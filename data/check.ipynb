# %%
import numpy as np
import torch
import torchvision
from torch.utils.data import Dataset
import os
from PIL import Image
from typing import Callable, Optional
from torch.utils.data import DataLoader
from torchvision import transforms
from load_data import load_data, FashionDataset, show_image
import matplotlib.pyplot as plt

# %%
train_iter = load_data(is_train = True)

# %%
train_iter

# %%
for i, X in enumerate(train_iter):
    print(i)
    print(X['image'].size())
    print(X['label'])
    break
# Out:
# 0
# torch.Size([256, 3, 224, 224])
# tensor([1, 2, 2, 2, 0, 2, 2, 3, 6, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 5, 0, 0, 1, 2,
#         0, 1, 0, 5, 5, 2, 2, 1, 1, 2, 0, 0, 5, 0, 0, 2, 5, 1, 0, 2, 1, 2, 1, 5,
#         2, 2, 2, 2, 0, 2, 0, 2, 0, 3, 2, 2, 1, 0, 0, 2, 2, 0, 5, 2, 2, 2, 3, 3,
#         2, 0, 2, 2, 2, 3, 3, 5, 6, 3, 2, 0, 1, 2, 2, 1, 2, 2, 2, 3, 0, 2, 0, 1,
#         1, 2, 1, 2, 1, 2, 3, 3, 0, 2, 2, 1, 0, 3, 5, 2, 2, 0, 2, 0, 2, 3, 2, 2,
#         0, 0, 3, 2, 2, 2, 2, 1, 2, 0, 4, 2, 0, 2, 2, 2, 2, 2, 2, 3, 3, 5, 2, 2,
#         0, 5, 2, 2, 2, 1, 1, 2, 2, 2, 2, 3, 2, 0, 2, 0, 2, 1, 1, 2, 2, 2, 0, 2,
#         2, 2, 0, 5, 2, 2, 0, 2, 2, 2, 2, 2, 2, 3, 3, 0, 2, 3, 2, 0, 0, 1, 5, 6,
#         2, 2, 1, 1, 1, 0, 2, 2, 2, 0, 2, 5, 0, 2, 2, 5, 1, 0, 1, 0, 2, 2, 2, 2,
#         2, 3, 5, 2, 1, 5, 5, 1, 2, 2, 2, 1, 2, 3, 1, 2, 2, 2, 2, 2, 0, 3, 2, 2,
#         2, 2, 2, 3, 0, 2, 5, 1, 3, 0, 2, 2, 4, 1, 1, 0])

# %%
def display_image(image):
    plt.imshow(image.permute(1,2,0))
    
    
# plt.imshow()

# %%
for i, X in enumerate(train_iter):
    print(i)
    print(X['image'][0].type())
    print(X['image'][0])
    display_image(X['image'][0])
    print(X['label'][0])
    break
# Out:
# 0
# torch.FloatTensor
# tensor([[[0.9333, 0.9333, 0.9333,  ..., 0.9333, 0.9333, 0.9333],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9333, 0.9333, 0.9333],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9333, 0.9333, 0.9333],
#          ...,
#          [0.8941, 0.8941, 0.8941,  ..., 0.8314, 0.8353, 0.8353],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8353, 0.8392, 0.8392],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8392, 0.8431, 0.8431]],
#
#         [[0.9333, 0.9333, 0.9333,  ..., 0.9373, 0.9373, 0.9373],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9373, 0.9373, 0.9373],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9373, 0.9373, 0.9373],
#          ...,
#          [0.8941, 0.8941, 0.8941,  ..., 0.8275, 0.8314, 0.8314],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8314, 0.8353, 0.8353],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8353, 0.8392, 0.8392]],
#
#         [[0.9333, 0.9333, 0.9333,  ..., 0.9176, 0.9176, 0.9176],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9176, 0.9176, 0.9176],
#          [0.9333, 0.9333, 0.9333,  ..., 0.9176, 0.9176, 0.9176],
#          ...,
#          [0.8941, 0.8941, 0.8941,  ..., 0.8078, 0.8118, 0.8118],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8118, 0.8157, 0.8157],
#          [0.8980, 0.8980, 0.8980,  ..., 0.8157, 0.8196, 0.8196]]])
# tensor(5)
