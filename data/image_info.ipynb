# %%
import numpy as np
import torch
import torchvision
from torch.utils.data import Dataset
import os
from PIL import Image
from typing import Callable, Optional
from torch.utils.data import DataLoader
from torchvision import transforms
from read_data import FashionDataset
import matplotlib.pyplot as plt

# %%
train_aug = transforms.Compose([transforms.ToTensor()])

# %%
train_dataset = FashionDataset(is_val = False, transform = train_aug)

# %%
image0 = train_dataset[0]['image']
image0.size()
# Out:
# torch.Size([3, 300, 200])

# %%
plt.imshow(image0.permute(1, 2, 0))

# %%
image1 = train_dataset[1]['image']

# %%
plt.imshow(image1.permute(1, 2, 0))

# %%
len(train_dataset)
# Out:
# 5000

# %%
train_dataset[0]['label']
# Out:
# <generator object FashionDataset.__init__.<locals>.<genexpr> at 0x7ffc82337120>

# %%
val_dataset = FashionDataset(is_val = False, transform = train_aug)

# %%
val_dataset[0]
# Out:
# {'image': tensor([[[0.9255, 0.9255, 0.9255,  ..., 0.9176, 0.9176, 0.9176],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9176, 0.9176, 0.9176],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9176, 0.9176, 0.9176],
#           ...,
#           [0.7882, 0.7882, 0.7882,  ..., 0.7922, 0.7922, 0.7922],
#           [0.7882, 0.7882, 0.7882,  ..., 0.7922, 0.7922, 0.7922],
#           [0.7882, 0.7882, 0.7882,  ..., 0.7922, 0.7922, 0.7922]],
#
#          [[0.9255, 0.9255, 0.9255,  ..., 0.9216, 0.9216, 0.9216],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9216, 0.9216, 0.9216],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9216, 0.9216, 0.9216],
#           ...,
#           [0.7961, 0.7961, 0.7961,  ..., 0.7922, 0.7922, 0.7922],
#           [0.7961, 0.7961, 0.7961,  ..., 0.7922, 0.7922, 0.7922],
#           [0.7961, 0.7961, 0.7961,  ..., 0.7922, 0.7922, 0.7922]],
#
#          [[0.9255, 0.9255, 0.9255,  ..., 0.9294, 0.9294, 0.9294],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9294, 0.9294, 0.9294],
#           [0.9255, 0.9255, 0.9255,  ..., 0.9294, 0.9294, 0.9294],
#           ...,
#           [0.7922, 0.7922, 0.7922,  ..., 0.8000, 0.8000, 0.8000],
#           [0.7922, 0.7922, 0.7922,  ..., 0.8000, 0.8000, 0.8000],
#           [0.7922, 0.7922, 0.7922,  ..., 0.8000, 0.8000, 0.8000]]]),
#  'label': <generator object FashionDataset.__init__.<locals>.<genexpr> at 0x7ffc839f9e40>}

# %%
val_dataset = FashionDataset(is_val = False, transform = train_aug)
